# %% [markdown]
# ### Creating a 3D Plot of the PPMS Data: Current as a function of both temperature T and voltage V

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

q = -1.602E-19
kB = 1.3806E-23

#%matplotlib notebook

# %% [markdown]
# ### Import CSV Files

# %%
df = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_2 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)
df_3 = pd.read_csv(r'/Users/vinhtran/160K.csv', header = None)
df_4 = pd.read_csv(r'/Users/vinhtran/140K.csv', header = None)
df_5 = pd.read_csv(r'/Users/vinhtran/120K.csv', header = None)
df_6 = pd.read_csv(r'/Users/vinhtran/100K.csv', header = None)
df_7 = pd.read_csv(r'/Users/vinhtran/80K.csv', header = None)
df_8 = pd.read_csv(r'/Users/vinhtran/60K.csv', header = None)
df_9 = pd.read_csv(r'/Users/vinhtran/40K.csv', header = None)

data = pd.DataFrame.to_numpy(df)
data2 = pd.DataFrame.to_numpy(df_2)
data3 = pd.DataFrame.to_numpy(df_3)
data4 = pd.DataFrame.to_numpy(df_4)
data5 = pd.DataFrame.to_numpy(df_5)
data6 = pd.DataFrame.to_numpy(df_6)
data7 = pd.DataFrame.to_numpy(df_7)
data8 = pd.DataFrame.to_numpy(df_8)
data9 = pd.DataFrame.to_numpy(df_9)

# %% [markdown]
# ### From Data Generate X, Y, Z Axis Arrays
# 1. For each set of data (for a given temperature), we plot each point as an individual scatter point. We already have the voltage and current points. All we need to do now is generate for each set an array of the same length (100 points) with the corresponding constant temperature as well as extract the voltage and current and store into separate arrays which we do below.

# %%
X_200 = np.zeros(100)
for i in range(100):
    X_200[i] = 200
Y_200 = np.array(data[:,0])
Z_200 = np.array(data[:,1])

X_180 = np.zeros(100)
for i in range(100):
    X_180[i] = 180
Y_180 = np.array(data2[:,0])
Z_180 = np.array(data2[:,1])

X_160 = np.zeros(100)
for i in range(100):
    X_160[i] = 160
Y_160 = np.array(data3[:,0])
Z_160 = np.array(data3[:,1])


X_140 = np.zeros(100)
for i in range(100):
    X_140[i] = 140
Y_140 = np.array(data4[:,0])
Z_140 = np.array(data4[:,1])

X_120 = np.zeros(100)
for i in range(100):
    X_120[i] = 120
Y_120 = np.array(data5[:,0])
Z_120 = np.array(data5[:,1])

X_100 = np.zeros(100)
for i in range(100):
    X_100[i] = 100
Y_100 = np.array(data6[:,0])
Z_100 = np.array(data6[:,1])

X_80 = np.zeros(100)
for i in range(100):
    X_80[i] = 80
Y_80 = np.array(data7[:,0])
Z_80 = np.array(data7[:,1])

X_60 = np.zeros(100)
for i in range(100):
    X_60[i] = 60
Y_60 = np.array(data8[:,0])
Z_60 = np.array(data8[:,1])


X_40 = np.zeros(100)
for i in range(100):
    X_40[i] = 40
Y_40 = np.array(data9[:,0])
Z_40 = np.array(data9[:,1])

# %% [markdown]
# ### 3D Scatter Plot

# %%
fig = plt.figure()

ax = plt.axes(projection ='3d')
ax.set_xlabel("Temperature in Kelvin")

# set current label to be in scientific notation 
ax.ticklabel_format(axis='z',style='sci', scilimits=(0,0))

ax.set_ylabel("Voltage in Volts")
ax.set_zlabel("Current in Amps")
ax.set_title("Au-Si: I versus V, T for 40-200 K")

ax.scatter(X_200, Y_200, Z_200, color = '#023858', label = '200 K')
ax.scatter(X_180, Y_180, Z_180, color = '#045a8d', label = '180 K')
ax.scatter(X_160, Y_160, Z_160, color = '#0570b0', label = '160 K')
ax.scatter(X_140, Y_140, Z_140, color = '#3690c0', label = '140 K')
ax.scatter(X_120, Y_120, Z_120, color = '#74a9cf', label = '120 K')
ax.scatter(X_100, Y_100, Z_100, color = '#a6bddb', label = '100 K')
ax.scatter(X_80, Y_80, Z_80, color = '#C2DAF2', label = '80 K')
ax.scatter(X_60, Y_60, Z_60, color = '#d0d1e6', label = '60 K')
ax.scatter(X_40, Y_40, Z_40, color = '#ece7f2', label = '40 K')

plt.legend()


plt.rcParams['figure.figsize'] = [15, 10]
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">

# %%
df_295 = pd.read_csv(r'/Users/vinhtran/295K.csv', header = None)
df_285 = pd.read_csv(r'/Users/vinhtran/285K.csv', header = None)
df_275 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_265 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)
df_255 = pd.read_csv(r'/Users/vinhtran/255K.csv', header = None)
df_245 = pd.read_csv(r'/Users/vinhtran/245K.csv', header = None)
df_225 = pd.read_csv(r'/Users/vinhtran/225K.csv', header = None)
df_200 = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_180 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)


data_295 = pd.DataFrame.to_numpy(df_295)
data_285 = pd.DataFrame.to_numpy(df_285)
data_275 = pd.DataFrame.to_numpy(df_275)
data_265 = pd.DataFrame.to_numpy(df_265)
data_255 = pd.DataFrame.to_numpy(df_255)
data_245 = pd.DataFrame.to_numpy(df_245)
data_225 = pd.DataFrame.to_numpy(df_225)
data_200 = pd.DataFrame.to_numpy(df_200)
data_180 = pd.DataFrame.to_numpy(df_180)

# %%
def generation(temp_string):
    # fail attempt, doens't work, try again with like a data object... 
    X_temp_string = np.zeros(100)
    for i in range(100):
        X_temp_string[i] = 60
    Y_temp_string = np.array(data_temp_string[:,0])
    Z_temp_string = np.array(data_temp_string[:,1])

# %%
X_295 = np.zeros(100)
for i in range(100):
    X_295[i] = 295
Y_295 = np.array(data_295[:,0])
Z_295 = np.array(data_295[:,1])


X_285 = np.zeros(100)
for i in range(100):
    X_285[i] = 285
Y_285 = np.array(data_285[:,0])
Z_285 = np.array(data_285[:,1])


X_275 = np.zeros(100)
for i in range(100):
    X_275[i] = 275
Y_275 = np.array(data_275[:,0])
Z_275 = np.array(data_275[:,1])


X_265 = np.zeros(100)
for i in range(100):
    X_265[i] = 265
Y_265 = np.array(data_265[:,0])
Z_265 = np.array(data_265[:,1])


X_255 = np.zeros(100)
for i in range(100):
    X_255[i] = 255
Y_255 = np.array(data_255[:,0])
Z_255 = np.array(data_255[:,1])


X_245 = np.zeros(100)
for i in range(100):
    X_245[i] = 245
Y_245 = np.array(data_245[:,0])
Z_245 = np.array(data_245[:,1])


X_225 = np.zeros(100)
for i in range(100):
    X_225[i] = 225
Y_225 = np.array(data_225[:,0])
Z_225 = np.array(data_225[:,1])

X_200 = np.zeros(100)
for i in range(100):
    X_200[i] = 200
Y_200 = np.array(data_200[:,0])
Z_200 = np.array(data_200[:,1])

X_180 = np.zeros(100)
for i in range(100):
    X_180[i] = 180
Y_180 = np.array(data_180[:,0])
Z_180 = np.array(data_180[:,1])

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.set_xlabel("Temperature in Kelvin")
ax.ticklabel_format(axis='z',style='sci', scilimits=(0,0))
ax.set_ylabel("Voltage in Volts")
ax.set_zlabel("Current in Amps")
ax.set_title("Au-Si: I vs V,T for 180-295 K")
ax.scatter(X_295, Y_295, Z_295, color = '#49006a', label = '295 K')
ax.scatter(X_285, Y_285, Z_285, color = '#7a0177', label = '285 K')
ax.scatter(X_275, Y_275, Z_275, color = '#ae017e', label = '275 K')
ax.scatter(X_265, Y_265, Z_265, color = '#dd3497', label = '265 K')
ax.scatter(X_255, Y_255, Z_255, color = '#f768a1', label = '255 K')
ax.scatter(X_245, Y_245, Z_245, color = '#fa9fb5', label = '245 K')
ax.scatter(X_225, Y_225, Z_225, color = '#fcc5c0', label = '225 K')
ax.scatter(X_200, Y_200, Z_200, color = '#fde0dd', label = '200 K')
ax.scatter(X_180, Y_180, Z_180, color = '#e7e1ef', label = '180 K')
plt.legend()
plt.rcParams['figure.figsize'] = [15, 10]
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ### Slicing via voltages

# %%
df_295 = pd.read_csv(r'/Users/vinhtran/295K.csv', header = None)
df_285 = pd.read_csv(r'/Users/vinhtran/285K.csv', header = None)
df_275 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_265 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)

# %%
# Extract voltages array from any given data frame. First convert to numpy array and take first column. 
data_295 = df_295.to_numpy()
voltage_array = data_295[:,0]
voltage_array;

# %%
# Generate new dataframe with columns labels as voltages and row label as temperature
A = np.reshape(data_295[:,1],(1,100))
data_295_new = pd.DataFrame(data = A, index = ['295'], columns = voltage_array)
data_295_new
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...   0.00006  0.000062  0.000065
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078   0.00008  0.000084  0.000084
#
# [1 rows x 100 columns]

# %%
result = 0

# %%
# Test concentacation...  
data_285 = df_285.to_numpy()
A = np.reshape(data_285[:,1], (1,100))
data_285_new = pd.DataFrame(data = A, index = ['285'], columns = voltage_array)
result = pd.concat([data_295_new, data_285_new])
result
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
# 285 -0.000028 -0.000020 -0.000014 -0.000007 -0.000007 -0.000006 -0.000004
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...   0.00006  0.000062  0.000065
# 285 -0.000003 -0.000002 -0.000003  ...   0.00006  0.000062  0.000065
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078   0.00008  0.000084  0.000084
# 285  0.000072  0.000073  0.000075  0.000078   0.00008  0.000084  0.000084
#
# [2 rows x 100 columns]

# %%
# Add all other files... 
df_275 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_265 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)
df_255 = pd.read_csv(r'/Users/vinhtran/255K.csv', header = None)
df_245 = pd.read_csv(r'/Users/vinhtran/245K.csv', header = None)
df_225 = pd.read_csv(r'/Users/vinhtran/225K.csv', header = None)
df_200 = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_180 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)
df_160 = pd.read_csv(r'/Users/vinhtran/160K.csv', header = None)
df_140 = pd.read_csv(r'/Users/vinhtran/140K.csv', header = None)
df_120 = pd.read_csv(r'/Users/vinhtran/120K.csv', header = None)
df_100 = pd.read_csv(r'/Users/vinhtran/100K.csv', header = None)
df_80 = pd.read_csv(r'/Users/vinhtran/80K.csv', header = None)
df_60 = pd.read_csv(r'/Users/vinhtran/60K.csv', header = None)
df_40 = pd.read_csv(r'/Users/vinhtran/40K.csv', header = None)
df_20 = pd.read_csv(r'/Users/vinhtran/20K.csv', header = None)

# %%
data_array = np.array([data_295, data_285, data_275, data_265, data_255, data_245, data_225,\
                      data_200, data_180, data_160, data_140, data_120, data_100,\
                      data_80, data_60, data_40, data_20]);

data_frame_array = np.array([df_295, df_285, df_275, df_265, df_255, df_245, df_225,\
                      df_200, df_180, df_160, df_140, df_120, df_100,\
                      df_80, df_60, df_40, df_20]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-47516fe6b9f4> in <module>
#       1 data_array = np.array([data_295, data_285, data_275, data_265, data_255, data_245, data_225,\
# ----> 2                       data_200, data_180, data_160, data_140, data_120, data_100,\
#       3                       data_80, data_60, data_40, data_20]);
#       4
#       5 data_frame_array = np.array([df_295, df_285, df_275, df_265, df_255, df_245, df_225,\
#
# NameError: name 'data_160' is not defined

# %%
data_275 = df_275.to_numpy()
A = np.reshape(data_275[:,1], (1,100))
data_275_new = pd.DataFrame(data = A, index = ['275'], columns = voltage_array)
result = pd.concat([result, data_275_new])
result
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
# 285 -0.000028 -0.000020 -0.000014 -0.000007 -0.000007 -0.000006 -0.000004
# 275 -0.000028 -0.000025 -0.000021 -0.000017 -0.000014 -0.000011 -0.000009
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...  0.000060  0.000062  0.000065
# 285 -0.000003 -0.000002 -0.000003  ...  0.000060  0.000062  0.000065
# 275 -0.000008 -0.000007 -0.000006  ...  0.000073  0.000075  0.000078
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078  0.000080  0.000084  0.000084
# 285  0.000072  0.000073  0.000075  0.000078  0.000080  0.000084  0.000084
# 275  0.000080  0.000083  0.000085  0.000089  0.000091  0.000093  0.000096
#
# [3 rows x 100 columns]

# %%
data_265 = df_265.to_numpy()
A = np.reshape(data_265[:,1], (1,100))
data_265_new = pd.DataFrame(data = A, index = ['265'], columns = voltage_array)
result = pd.concat([result, data_265_new])

data_255 = df_255.to_numpy()
A = np.reshape(data_255[:,1], (1,100))
data_255_new = pd.DataFrame(data = A, index = ['255'], columns = voltage_array)
result = pd.concat([result, data_255_new])

data_245 = df_245.to_numpy()
A = np.reshape(data_245[:,1], (1,100))
data_245_new = pd.DataFrame(data = A, index = ['245'], columns = voltage_array)
result = pd.concat([result, data_245_new])

data_225 = df_225.to_numpy()
A = np.reshape(data_225[:,1], (1,100))
data_225_new = pd.DataFrame(data = A, index = ['225'], columns = voltage_array)
result = pd.concat([result, data_225_new])

data_200 = df_200.to_numpy()
A = np.reshape(data_200[:,1], (1,100))
data_200_new = pd.DataFrame(data = A, index = ['200'], columns = voltage_array)
result = pd.concat([result, data_200_new])

data_180 = df_180.to_numpy()
A = np.reshape(data_180[:,1], (1,100))
data_180_new = pd.DataFrame(data = A, index = ['180'], columns = voltage_array)
result = pd.concat([result, data_180_new])

data_160 = df_160.to_numpy()
A = np.reshape(data_160[:,1], (1,100))
data_160_new = pd.DataFrame(data = A, index = ['160'], columns = voltage_array)
result = pd.concat([result, data_160_new])

data_140 = df_140.to_numpy()
A = np.reshape(data_140[:,1], (1,100))
data_140_new = pd.DataFrame(data = A, index = ['140'], columns = voltage_array)
result = pd.concat([result, data_140_new])

data_120 = df_120.to_numpy()
A = np.reshape(data_120[:,1], (1,100))
data_120_new = pd.DataFrame(data = A, index = ['120'], columns = voltage_array)
result = pd.concat([result, data_120_new])

data_100 = df_100.to_numpy()
A = np.reshape(data_100[:,1], (1,100))
data_100_new = pd.DataFrame(data = A, index = ['100'], columns = voltage_array)
result = pd.concat([result, data_100_new])

data_80 = df_80.to_numpy()
A = np.reshape(data_80[:,1], (1,100))
data_80_new = pd.DataFrame(data = A, index = ['80'], columns = voltage_array)
result = pd.concat([result, data_80_new])

data_60 = df_60.to_numpy()
A = np.reshape(data_60[:,1], (1,100))
data_60_new = pd.DataFrame(data = A, index = ['60'], columns = voltage_array)
result = pd.concat([result, data_60_new])

data_40 = df_40.to_numpy()
A = np.reshape(data_40[:,1], (1,100))
data_40_new = pd.DataFrame(data = A, index = ['40'], columns = voltage_array)
result = pd.concat([result, data_40_new])

data_20 = df_20.to_numpy()
A = np.reshape(data_20[:,1], (1,100))
data_20_new = pd.DataFrame(data = A, index = ['20'], columns = voltage_array)
result = pd.concat([result, data_20_new])

# %%
# Extract the columns... 
result[-4.99462]
# Out:
# 295   -4.600000e-05
# 285   -2.841000e-05
# 275   -2.824000e-05
# 265   -3.088000e-05
# 255   -1.538000e-05
# 245   -2.170000e-06
# 225   -6.000000e-07
# 200   -8.000000e-08
# 180   -2.400000e-07
# 160   -1.290000e-06
# 140   -1.310000e-06
# 120   -1.260000e-06
# 100   -1.020000e-06
# 80    -9.100000e-07
# 60    -8.300000e-07
# 40    -2.400000e-07
# 20    -2.900000e-07
# Name: -4.99462, dtype: float64

# %%
Fixed_result = result;

# %%
V_5 = result[4.99823].to_numpy()

# %%
Temp_values = result.index.values
Temp_values
# Out:
# array(['295', '285', '275', '265', '255', '245', '225', '200', '180',
#        '160', '140', '120', '100', '80', '60', '40', '20'], dtype=object)

# %%
Temp_values = np.array([295, 285, 275, 265, 255, 245, 225, 200, 180, 160, 140,\
                       120, 100, 80, 60, 40, 20])

# %%
plt.plot(Temp_values, V_5)

# %%
T = np.reshape(Temp_values, (1,17))
I = np.reshape(V_5, (1,17))

# %%
Data_matrix = Fixed_result.to_numpy()
I_V5 = Data_matrix[:,99]

# %%
x = np.linspace(0,5,100)
y = np.sin(x)
plt.plot(x,y)
plt.show()
