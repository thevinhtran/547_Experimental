# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_2 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)
df_3 = pd.read_csv(r'/Users/vinhtran/160K.csv', header = None)
df_4 = pd.read_csv(r'/Users/vinhtran/140K.csv', header = None)
df_5 = pd.read_csv(r'/Users/vinhtran/120K.csv', header = None)
df_6 = pd.read_csv(r'/Users/vinhtran/100K.csv', header = None)
df_7 = pd.read_csv(r'/Users/vinhtran/80K.csv', header = None)
df_8 = pd.read_csv(r'/Users/vinhtran/60K.csv', header = None)
df_9 = pd.read_csv(r'/Users/vinhtran/20K.csv', header = None)

data = pd.DataFrame.to_numpy(df)
data2 = pd.DataFrame.to_numpy(df_2)
data3 = pd.DataFrame.to_numpy(df_3)
data4 = pd.DataFrame.to_numpy(df_4)
data5 = pd.DataFrame.to_numpy(df_5)
data6 = pd.DataFrame.to_numpy(df_6)
data7 = pd.DataFrame.to_numpy(df_7)
data8 = pd.DataFrame.to_numpy(df_8)
data9 = pd.DataFrame.to_numpy(df_9)

# %%
for i in range(51,len(data[:,0])):
    data[i,1] = data[i,1] - data[51,1]
for i in range(51):
    data[i,1] = data[i,1] + data[51,1]

for i in range(51,len(data2[:,0])):
    data2[i,1] = data2[i,1] - data2[51,1]
for i in range(31):
    data2[i,1] = data2[i,1] + data2[51,1]
    
for i in range(51,len(data3[:,0])):
    data3[i,1] = data3[i,1] - data3[51,1]
for i in range(51):
    data3[i,1] = data3[i,1] + data3[51,1]
    
for i in range(51,len(data4[:,0])):
    data4[i,1] = data4[i,1] - data4[51,1]
for i in range(51):
    data4[i,1] = data4[i,1] + data4[51,1]
    
for i in range(51,len(data5[:,0])):
    data5[i,1] = data5[i,1] - data5[51,1]
for i in range(51):
    data5[i,1] = data5[i,1] + data5[51,1]

for i in range(51,len(data6[:,0])):
    data6[i,1] = data6[i,1] - data6[51,1]
for i in range(51):
    data6[i,1] = data6[i,1] + data6[51,1]

# %%
B = np.linspace(-5,5,50);
C = np.linspace(-0.00001,0.00010,50);
A = np.zeros(50);

# %%
plt.plot(data9[:,0], data9[:,1], '.-', color = '#fff7fb', label = '40 K')
plt.plot(data8[:,0], data8[:,1], '.-', color = '#ece7f2', label = '80 K')
plt.plot(data7[:,0], data7[:,1], '.-', color = '#d0d1e6', label = '100 K')
plt.plot(data6[:,0], data6[:,1], '.-', color = '#a6bddb', label = '120 K')
plt.plot(data5[:,0], data5[:,1], '.-', color = '#74a9cf', label = '140 K')
plt.plot(data4[:,0], data4[:,1], '.-', color = '#3690c0', label = '160 K')
plt.plot(data3[:,0], data3[:,1], '.-', color = '#0570b0', label = '180 K')
plt.plot(data2[:,0], data2[:,1], '.-', color = '#045a8d', label = '200 K')
plt.plot(data[:,0], data[:,1], '.-', color = '#023858', label = '225 K')


plt.legend(loc = 0)
plt.plot(B,A, '--', color = 'black')
plt.plot(A,C, '--', color = 'black')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
#plt.grid()
plt.xlabel("Voltage $V$ in Volts")
plt.ylabel("Current $I$ in Amps")
plt.grid()
plt.title("IV Characteristics Au-Si 40-225 K")
plt.savefig('Variable_Temp_Cool.pdf', bbox_inches='tight')

# %%
plt.savefig('PPMS_Room_Temp.pdf')

# %%
df = pd.read_csv(r'/Users/vinhtran/300K.csv', header = None)
df_2 = pd.read_csv(r'/Users/vinhtran/295KK.csv', header = None)
df_3 = pd.read_csv(r'/Users/vinhtran/290K.csv', header = None)
df_4 = pd.read_csv(r'/Users/vinhtran/285KK.csv', header = None)
df_5 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_6 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)
df_7 = pd.read_csv(r'/Users/vinhtran/255K.csv', header = None)
df_8 = pd.read_csv(r'/Users/vinhtran/245K.csv', header = None)
df_9 = pd.read_csv(r'/Users/vinhtran/225K.csv', header = None)

df_10 = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_11 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)
df_12 = pd.read_csv(r'/Users/vinhtran/160K.csv', header = None)
df_13 = pd.read_csv(r'/Users/vinhtran/140K.csv', header = None)
df_14 = pd.read_csv(r'/Users/vinhtran/120K.csv', header = None)
df_15 = pd.read_csv(r'/Users/vinhtran/100K.csv', header = None)
df_16 = pd.read_csv(r'/Users/vinhtran/80K.csv', header = None)
df_17 = pd.read_csv(r'/Users/vinhtran/60K.csv', header = None)
df_18 = pd.read_csv(r'/Users/vinhtran/20K.csv', header = None)

data = pd.DataFrame.to_numpy(df)
data2 = pd.DataFrame.to_numpy(df_2)
data3 = pd.DataFrame.to_numpy(df_3)
data4 = pd.DataFrame.to_numpy(df_4)
data5 = pd.DataFrame.to_numpy(df_5)
data6 = pd.DataFrame.to_numpy(df_6)
data7 = pd.DataFrame.to_numpy(df_7)
data8 = pd.DataFrame.to_numpy(df_8)
data9 = pd.DataFrame.to_numpy(df_9)
data10 = pd.DataFrame.to_numpy(df_10)
data11 = pd.DataFrame.to_numpy(df_11)
data12 = pd.DataFrame.to_numpy(df_12)
data13 = pd.DataFrame.to_numpy(df_13)
data14 = pd.DataFrame.to_numpy(df_14)
data15 = pd.DataFrame.to_numpy(df_15)
data16 = pd.DataFrame.to_numpy(df_16)
data17 = pd.DataFrame.to_numpy(df_17)
data18 = pd.DataFrame.to_numpy(df_18)

# %%
#plt.plot(data[:,0], data[:,1], '.-', color = '#49006a', label = '300 K')
plt.plot(data2[:,0], data2[:,1], '.-', color = '#49006a', label = '295 K')
#plt.plot(data3[:,0], data3[:,1], '.-', color = '#7a0177', label = '290 K')
plt.plot(data4[:,0], data4[:,1], '.-', color = '#7a0177', label = '285 K')
plt.plot(data5[:,0], data5[:,1], '.-', color = '#ae017e', label = '275 K')
plt.plot(data6[:,0], data6[:,1], '.-', color = '#dd3497', label = '265 K')
plt.plot(data7[:,0], data7[:,1], '.-', color = '#f768a1', label = '255 K')
plt.plot(data8[:,0], data8[:,1], '.-', color = '#fa9fb5', label = '245 K')
plt.plot(data9[:,0], data9[:,1], '.-', color = '#fcc5c0', label = '225 K')

plt.plot(data10[:,0], data10[:,1], '.-', color = '#fff7fb', label = '200 K)
plt.plot(data11[:,0], data11[:,1], '.-', color = '#fcc5c0', label = '180 K')
plt.plot(data12[:,0], data12[:,1], '.-', color = '#fcc5c0', label = '160 K')
plt.plot(data13[:,0], data13[:,1], '.-', color = '#fcc5c0', label = '140 K')
plt.plot(data14[:,0], data14[:,1], '.-', color = '#fcc5c0', label = '120 K')
plt.plot(data15[:,0], data15[:,1], '.-', color = '#fcc5c0', label = '100 K')
plt.plot(data16[:,0], data16[:,1], '.-', color = '#fcc5c0', label = '80 K')
plt.plot(data17[:,0], data17[:,1], '.-', color = '#fcc5c0', label = '60 K')
plt.plot(data18[:,0], data18[:,1], '.-', color = '#fcc5c0', label = '40 K')



plt.legend(loc = 0)
plt.plot(B,A, '--', color = 'black')
plt.plot(A,C, '--', color = 'black')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
#plt.grid()
plt.xlabel("Voltage $V$ in Volts")
plt.ylabel("Current $I$ in Amps")
plt.grid()
plt.title("IV Characteristics Au-Si Warmer Temperatures")
plt.savefig('Variable_Temp_Warm_5.pdf', bbox_inches='tight')

# %%
plt.show()

# %%
F = np.linspace(-3,3,50);
E = np.linspace(-0.00000011,0.000004,50);
G = np.zeros(50);
plt.plot(data3[:,0], data3[:,1], '.-', color = 'royalblue', label = 'Probe Station')
plt.legend(loc = 0)
plt.plot(F,G, '--', color = 'black')
plt.plot(G,E, '--', color = 'black')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("Voltage $V$ in Volts")
plt.ylabel("Current $I$ in Amps")
plt.grid()
plt.title("Probe Station")
plt.savefig('Probe_Station.pdf')
