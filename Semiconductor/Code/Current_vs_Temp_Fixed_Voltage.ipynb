# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import csv
import sklearn as sk

# %%
df_295 = pd.read_csv(r'/Users/vinhtran/295K.csv', header = None)
df_285 = pd.read_csv(r'/Users/vinhtran/285KK.csv', header = None)
df_275 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_265 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)

# %%
# Extract voltages array from any given data frame. First convert to numpy array and take first column. 
data_295 = df_295.to_numpy()
voltage_array = data_295[:,0]
voltage_array;
result = 0

# %%
# Generate new dataframe with columns labels as voltages and row label as temperature
A = np.reshape(data_295[:,1],(1,100))
data_295_new = pd.DataFrame(data = A, index = ['295'], columns = voltage_array)
data_295_new
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...   0.00006  0.000062  0.000065
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078   0.00008  0.000084  0.000084
#
# [1 rows x 100 columns]

# %%
# Test concentacation...  
result = 0
data_285 = df_285.to_numpy()
A = np.reshape(data_285[:,1], (1,100))
data_285_new = pd.DataFrame(data = A, index = ['285'], columns = voltage_array)
result = pd.concat([data_295_new, data_285_new])
result
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
# 285 -0.000028 -0.000020 -0.000014 -0.000007 -0.000007 -0.000006 -0.000004
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...  0.000060  0.000062  0.000065
# 285 -0.000003 -0.000002 -0.000003  ...  0.000067  0.000070  0.000072
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078  0.000080  0.000084  0.000084
# 285  0.000074  0.000077  0.000080  0.000082  0.000085  0.000088  0.000090
#
# [2 rows x 100 columns]

# %%
# Add all other files... 
df_275 = pd.read_csv(r'/Users/vinhtran/275K.csv', header = None)
df_265 = pd.read_csv(r'/Users/vinhtran/265K.csv', header = None)
df_255 = pd.read_csv(r'/Users/vinhtran/255K.csv', header = None)
df_245 = pd.read_csv(r'/Users/vinhtran/245K.csv', header = None)
df_225 = pd.read_csv(r'/Users/vinhtran/225K.csv', header = None)
df_200 = pd.read_csv(r'/Users/vinhtran/200K.csv', header = None)
df_180 = pd.read_csv(r'/Users/vinhtran/180K.csv', header = None)
df_160 = pd.read_csv(r'/Users/vinhtran/160K.csv', header = None)
df_140 = pd.read_csv(r'/Users/vinhtran/140K.csv', header = None)
df_120 = pd.read_csv(r'/Users/vinhtran/120K.csv', header = None)
df_100 = pd.read_csv(r'/Users/vinhtran/100K.csv', header = None)
df_80 = pd.read_csv(r'/Users/vinhtran/80K.csv', header = None)
df_60 = pd.read_csv(r'/Users/vinhtran/60K.csv', header = None)
df_40 = pd.read_csv(r'/Users/vinhtran/40K.csv', header = None)
df_20 = pd.read_csv(r'/Users/vinhtran/20K.csv', header = None)

# %%
data_275 = df_275.to_numpy()
A = np.reshape(data_275[:,1], (1,100))
data_275_new = pd.DataFrame(data = A, index = ['275'], columns = voltage_array)
result = pd.concat([result, data_275_new])
result
# Out:
#      -4.99462  -4.89611  -4.79483  -4.69300  -4.59151  -4.48930  -4.38854  \
# 295 -0.000046 -0.000039 -0.000032 -0.000031 -0.000028 -0.000021 -0.000018
# 285 -0.000028 -0.000020 -0.000014 -0.000007 -0.000007 -0.000006 -0.000004
# 275 -0.000028 -0.000025 -0.000021 -0.000017 -0.000014 -0.000011 -0.000009
#
#      -4.28507  -4.18299  -4.08132  ...   4.08006   4.18222   4.28405  \
# 295 -0.000015 -0.000014 -0.000013  ...  0.000060  0.000062  0.000065
# 285 -0.000003 -0.000002 -0.000003  ...  0.000067  0.000070  0.000072
# 275 -0.000008 -0.000007 -0.000006  ...  0.000073  0.000075  0.000078
#
#       4.38614   4.48802   4.58926   4.69162   4.79437   4.89604   4.99823
# 295  0.000072  0.000073  0.000075  0.000078  0.000080  0.000084  0.000084
# 285  0.000074  0.000077  0.000080  0.000082  0.000085  0.000088  0.000090
# 275  0.000080  0.000083  0.000085  0.000089  0.000091  0.000093  0.000096
#
# [3 rows x 100 columns]

# %%
data_265 = df_265.to_numpy()
A = np.reshape(data_265[:,1], (1,100))
data_265_new = pd.DataFrame(data = A, index = ['265'], columns = voltage_array)
result = pd.concat([result, data_265_new])

data_255 = df_255.to_numpy()
A = np.reshape(data_255[:,1], (1,100))
data_255_new = pd.DataFrame(data = A, index = ['255'], columns = voltage_array)
result = pd.concat([result, data_255_new])

data_245 = df_245.to_numpy()
A = np.reshape(data_245[:,1], (1,100))
data_245_new = pd.DataFrame(data = A, index = ['245'], columns = voltage_array)
result = pd.concat([result, data_245_new])

data_225 = df_225.to_numpy()
A = np.reshape(data_225[:,1], (1,100))
data_225_new = pd.DataFrame(data = A, index = ['225'], columns = voltage_array)
result = pd.concat([result, data_225_new])

data_200 = df_200.to_numpy()
A = np.reshape(data_200[:,1], (1,100))
data_200_new = pd.DataFrame(data = A, index = ['200'], columns = voltage_array)
result = pd.concat([result, data_200_new])

data_180 = df_180.to_numpy()
A = np.reshape(data_180[:,1], (1,100))
data_180_new = pd.DataFrame(data = A, index = ['180'], columns = voltage_array)
result = pd.concat([result, data_180_new])

data_160 = df_160.to_numpy()
A = np.reshape(data_160[:,1], (1,100))
data_160_new = pd.DataFrame(data = A, index = ['160'], columns = voltage_array)
result = pd.concat([result, data_160_new])

data_140 = df_140.to_numpy()
A = np.reshape(data_140[:,1], (1,100))
data_140_new = pd.DataFrame(data = A, index = ['140'], columns = voltage_array)
result = pd.concat([result, data_140_new])

data_120 = df_120.to_numpy()
A = np.reshape(data_120[:,1], (1,100))
data_120_new = pd.DataFrame(data = A, index = ['120'], columns = voltage_array)
result = pd.concat([result, data_120_new])

data_100 = df_100.to_numpy()
A = np.reshape(data_100[:,1], (1,100))
data_100_new = pd.DataFrame(data = A, index = ['100'], columns = voltage_array)
result = pd.concat([result, data_100_new])

data_80 = df_80.to_numpy()
A = np.reshape(data_80[:,1], (1,100))
data_80_new = pd.DataFrame(data = A, index = ['80'], columns = voltage_array)
result = pd.concat([result, data_80_new])

data_60 = df_60.to_numpy()
A = np.reshape(data_60[:,1], (1,100))
data_60_new = pd.DataFrame(data = A, index = ['60'], columns = voltage_array)
result = pd.concat([result, data_60_new])

data_40 = df_40.to_numpy()
A = np.reshape(data_40[:,1], (1,100))
data_40_new = pd.DataFrame(data = A, index = ['40'], columns = voltage_array)
result = pd.concat([result, data_40_new])

data_20 = df_20.to_numpy()
A = np.reshape(data_20[:,1], (1,100))
data_20_new = pd.DataFrame(data = A, index = ['20'], columns = voltage_array)
result = pd.concat([result, data_20_new])

# %%
pd.set_option('display.max_columns', None)
result
# Out:
#         -4.994620     -4.896110     -4.794830     -4.693000     -4.591510  \
# 295 -4.600000e-05 -3.924000e-05 -3.200000e-05 -3.090000e-05 -2.750000e-05
# 285 -2.841000e-05 -1.992000e-05 -1.354000e-05 -6.530000e-06 -7.150000e-06
# 275 -2.824000e-05 -2.539000e-05 -2.140000e-05 -1.715000e-05 -1.397000e-05
# 265 -3.088000e-05 -1.628000e-05 -1.088000e-05 -8.300000e-06 -6.990000e-06
# 255 -1.538000e-05 -1.577000e-05 -1.539000e-05 -1.112000e-05 -8.990000e-06
# 245 -2.170000e-06 -1.480000e-06 -1.100000e-06 -8.600000e-07 -7.400000e-07
# 225 -6.000000e-07 -4.700000e-07 -3.700000e-07 -3.300000e-07 -2.700000e-07
# 200 -8.000000e-08 -7.000000e-08 -8.000000e-08 -7.000000e-08 -7.000000e-08
# 180 -2.400000e-07 -2.300000e-07 -2.000000e-07 -2.100000e-07 -2.100000e-07
# 160 -1.290000e-06 -1.220000e-06 -1.220000e-06 -1.250000e-06 -1.270000e-06
# 140 -1.310000e-06 -1.300000e-06 -1.330000e-06 -1.290000e-06 -1.320000e-06
# 120 -1.260000e-06 -1.210000e-06 -1.300000e-06 -1.220000e-06 -8.700000e-07
# ...

# %%
Temp_values = result.index.values
V_5 = result[4.99823].to_numpy()
V_4 = result[4.080060].to_numpy()
V_3 = result[3.059050].to_numpy()
V_2 = result[2.038440].to_numpy()
V_1 = result[1.018530].to_numpy()
V_neg_1 = result[-1.019650].to_numpy()
V_neg_2 = result[-2.039750].to_numpy()
V_neg_3 = result[-3.059930].to_numpy()
V_neg_4 = result[-4.081320].to_numpy()
V_neg_5 = result[	-4.994620].to_numpy()

# %%
plt.scatter(Temp_values, V_5, label = '5 V', color = '#225ea8')
plt.scatter(Temp_values, V_4, label = '4 V', color = '#1d91c0')
plt.scatter(Temp_values, V_3, label = '3 V', color = '#41b6c4')
plt.scatter(Temp_values, V_2, label = '2 V', color = '#7fcdbb')
plt.scatter(Temp_values, V_1, label = '1 V', color = '#c7e9b4')
plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("Temperature T in K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("Current $I$ in Amps")
plt.title("Au-Si I vs T for fixed V")
plt.savefig('Temp_Dependence.pdf', bbox_inches='tight')

# %%
plt.scatter(Temp_values, V_neg_5, label = '-5 V', color = '#225ea8')
plt.scatter(Temp_values, V_neg_4, label = '-4 V', color = '#1d91c0')
plt.scatter(Temp_values, V_neg_3, label = '-3 V', color = '#41b6c4')
plt.scatter(Temp_values, V_neg_2, label = '-2 V', color = '#7fcdbb')
plt.scatter(Temp_values, V_neg_1, label = '-1 V', color = '#c7e9b4')
plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("Temperature T in K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("Current $I$ in Amps")
plt.title("Au-Si I vs T for fixed V")
plt.savefig('Temp_Dependence.pdf', bbox_inches='tight')

# %%
inv_V_neg_5 = np.zeros(len(V_neg_5)-2)
inv_V_neg_4 = np.zeros(len(V_neg_4)-2)
inv_V_neg_3 = np.zeros(len(V_neg_3)-2)
inv_V_neg_2 = np.zeros(len(V_neg_2)-2)
inv_V_neg_1 = np.zeros(len(V_neg_1)-2)
inv_temp = np.zeros(len(V_neg_1)-2)

for i in range(len(V_neg_3)-2):
    inv_V_neg_5[i] = np.log(-V_neg_5[i]/int(Temp_values[i])**2)
    #inv_V_neg_5[i] = V_neg_5[i]/int(Temp_values[i])**2
    inv_temp[i] = 1/int(Temp_values[i])

for i in range(len(V_neg_3)-2):
    inv_V_neg_4[i] = np.log(-V_neg_4[i]/int(Temp_values[i])**2)
    #inv_V_neg_4[i] = V_neg_4[i]/int(Temp_values[i])**2


for i in range(len(V_neg_3)-2):
    inv_V_neg_3[i] = np.log(-V_neg_3[i]/int(Temp_values[i])**2)
    #inv_V_neg_3[i] = V_neg_3[i]/int(Temp_values[i])**2

for i in range(len(V_neg_3)-2):
    inv_V_neg_2[i] = np.log(-V_neg_2[i]/int(Temp_values[i])**2)
    #inv_V_neg_2[i] = V_neg_2[i]/int(Temp_values[i])**2

for i in range(len(V_neg_3)-2):
    inv_V_neg_1[i] = np.log(-V_neg_1[i]/int(Temp_values[i])**2)
    #inv_V_neg_1[i] = V_neg_1[i]/int(Temp_values[i])**2

# %%
plt.scatter(inv_temp, inv_V_neg_5, label = '-5 V', color = '#225ea8')
plt.scatter(inv_temp, inv_V_neg_4, label = '-4 V', color = '#1d91c0')
plt.scatter(inv_temp, inv_V_neg_3, label = '-3 V', color = '#41b6c4')
plt.scatter(inv_temp, inv_V_neg_2, label = '-2 V', color = '#7fcdbb')
plt.scatter(inv_temp, inv_V_neg_1, label = '-1 V', color = '#c7e9b4')
plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in inv. K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$ln(I/T^2)$")
plt.title("Au-Si $ln(I/T^2)$ vs $1/T$")
plt.savefig('Richardson_various_voltages.pdf', bbox_inches='tight')

# %%
for i in range(len(inv_temp)):
    print("{:.5f}".format(inv_temp[i]), ",", "{:.5f}".format(inv_V_neg_5[i]))
# Out:
# 0.00339 , -21.36082
# 0.00351 , -21.77375
# 0.00364 , -21.70831
# 0.00377 , -21.54486
# 0.00392 , -22.16497
# 0.00408 , -24.04330
# 0.00444 , -25.15854
# 0.00500 , -26.93787
# 0.00556 , -25.62854
# 0.00625 , -23.71122
# 0.00714 , -23.42877
# 0.00833 , -23.15938
# 0.01000 , -23.00605
# 0.01250 , -22.67387
# 0.01667 , -22.19053

# %%
inv_temp_trunc = np.zeros(len(inv_temp)-8)
inv_V_neg_5_trunc = np.zeros(len(inv_temp)-8)
inv_V_neg_4_trunc = np.zeros(len(inv_temp)-8)
inv_V_neg_3_trunc = np.zeros(len(inv_temp)-8)
inv_V_neg_2_trunc = np.zeros(len(inv_temp)-8)
inv_V_neg_1_trunc = np.zeros(len(inv_temp)-8)

for i in range(len(inv_temp)-8):
    inv_temp_trunc[i] = inv_temp[i]
    inv_V_neg_5_trunc[i] = inv_V_neg_5[i]
    inv_V_neg_4_trunc[i] = inv_V_neg_4[i]
    inv_V_neg_3_trunc[i] = inv_V_neg_3[i]
    inv_V_neg_2_trunc[i] = inv_V_neg_2[i]
    inv_V_neg_1_trunc[i] = inv_V_neg_1[i]

# %%
plt.scatter(inv_temp_trunc, inv_V_neg_5_trunc, label = '-5 V', color = '#2b8cbe')
m5, b5 = np.polyfit(inv_temp_trunc, inv_V_neg_5_trunc, 1)
print("m5 = ", "{:.4f}".format(m5), "b5 = ", "{:.4f}".format(b5))
plt.plot(inv_temp_trunc, m5*inv_temp_trunc + b5, color = 'black')

plt.scatter(inv_temp_trunc, inv_V_neg_4_trunc, label = '-4 V', color = '#a6bddb')

plt.scatter(inv_temp_trunc, inv_V_neg_3_trunc, label = '-3 V', color = '#ece7f2')
m3, b3 = np.polyfit(inv_temp_trunc, inv_V_neg_3_trunc, 1)
print("m3 = ", "{:.4f}".format(m3), "b3 = ", "{:.4f}".format(b3))
plt.plot(inv_temp_trunc, m3*inv_temp_trunc + b3, color = 'black')

#plt.scatter(inv_temp_trunc, inv_V_neg_2_trunc, label = '-2 V', color = '#7fcdbb')
#plt.scatter(inv_temp_trunc, inv_V_neg_1_trunc, label = '-1 V', color = '#c7e9b4')

m4, b4 = np.polyfit(inv_temp_trunc, inv_V_neg_4_trunc, 1)
print("m4 = ", "{:.4f}".format(m4), "b4 = ", "{:.4f}".format(b4))
plt.plot(inv_temp_trunc, m4*inv_temp_trunc + b4, color = 'black')

m2, b2 = np.polyfit(inv_temp_trunc, inv_V_neg_2_trunc, 1)
print("m2 = ", "{:.4f}".format(m2), "b2 = ", "{:.4f}".format(b2))

m1, b1 = np.polyfit(inv_temp_trunc, inv_V_neg_1_trunc, 1)
print("m1 = ", "{:.4f}".format(m1), "b1 = ", "{:.4f}".format(b1))


plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in $K^{-1}$")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$\ln(I/T^2)$")
plt.title("Linearized Log Plot: 225K to 295K")
plt.savefig('Richardson_various_voltages_trunc.pdf', bbox_inches='tight')
# Out:
# m5 =  -3732.0457 b5 =  -8.2713
# m3 =  -3287.2289 b3 =  -13.0116
# m4 =  -3225.1017 b4 =  -11.9117
# m2 =  -1506.1148 b2 =  -20.8879
# m1 =  759.0290 b1 =  -29.6314

# %%
#Boltzmann constant in units of eV K^-1
k = 8.617E-5
Area = 0.72
barrier_neg_5 = -m5*k
barrier_neg_4 = -m4*k
barrier_neg_3 = -m3*k
barrier_neg_2 = -m2*k
barrier_neg_1 = -m1*k

A_neg_5 = np.exp(b5)/Area
A_neg_4 = np.exp(b4)/Area
A_neg_3 = np.exp(b3)/Area
A_neg_2 = np.exp(b2)/Area
A_neg_1 = np.exp(b1)/Area
print("barrier_neg_5 = ", "{:.4f}".format(barrier_neg_5)," ", "A_5 = ", "{:4e}".format(A_neg_5))
print("barrier_neg_4 = ", "{:.4f}".format(barrier_neg_4)," ", "A_5 = ", "{:4e}".format(A_neg_4))
print("barrier_neg_3 = ", "{:.4f}".format(barrier_neg_3)," ", "A_5 = ", "{:4e}".format(A_neg_3))
print("barrier_neg_2 = ", "{:.4f}".format(barrier_neg_2)," ", "A_5 = ", "{:4e}".format(A_neg_2))
print("barrier_neg_1 = ", "{:.4f}".format(barrier_neg_1)," ", "A_5 = ", "{:4e}".format(A_neg_1))
# Out:
# barrier_neg_5 =  0.3216   A_5 =  3.552069e-04
# barrier_neg_4 =  0.2779   A_5 =  9.321248e-06
# barrier_neg_3 =  0.2833   A_5 =  3.103059e-06
# barrier_neg_2 =  0.1298   A_5 =  1.178051e-09
# barrier_neg_1 =  -0.0654   A_5 =  1.878871e-13

# %% [markdown]
# ### Non-Linear Inhomogeneous Barrier Height
# Assume Barrier heights are distributed Gaussian like... and propose a nonlinear test fit...

# %%
plt.scatter(inv_temp, inv_V_neg_5, label = '-5 V', color = '#225ea8')
sig_5, m5_new, b5_new = np.polyfit(inv_temp, inv_V_neg_5, 2)
print("sig_5 = ", "{:.4f}".format(sig_5), "m5 = ", "{:.4f}".format(m5_new), "b3 = ", "{:.4f}".format(b5_new))
plt.plot(inv_temp, sig_5*inv_temp**2 + m5_new*inv_temp + b5_new, color = 'black')

#plt.scatter(inv_temp, inv_V_neg_4, label = '-4 V', color = '#1d91c0')
#plt.scatter(inv_temp, inv_V_neg_3, label = '-3 V', color = '#41b6c4')
#plt.scatter(inv_temp, inv_V_neg_2, label = '-2 V', color = '#7fcdbb')
#plt.scatter(inv_temp, inv_V_neg_1, label = '-1 V', color = '#c7e9b4')

plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in inv. K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$ln(I/T^2)$")
plt.title("Au-Si $ln(I/T^2)$ vs $1/T$")

plt.savefig('Gaussian_Fit.pdf', bbox_inches='tight')
# Out:
# sig_5 =  42090.0783 m5 =  -748.4958 b3 =  -20.7244

# %%
for i in range(len(inv_temp)):
    print("{:.4f}".format(inv_temp[i]), ",", "{:.4f}".format(inv_V_neg_5[i]))
# Out:
# 0.0034 , -21.3608
# 0.0035 , -21.7737
# 0.0036 , -21.7083
# 0.0038 , -21.5449
# 0.0039 , -22.1650
# 0.0041 , -24.0433
# 0.0044 , -25.1585
# 0.0050 , -26.9379
# 0.0056 , -25.6285
# 0.0063 , -23.7112
# 0.0071 , -23.4288
# 0.0083 , -23.1594
# 0.0100 , -23.0060
# 0.0125 , -22.6739
# 0.0167 , -22.1905

# %%
V_neg_5
# Out:
# array([-4.600e-05, -2.841e-05, -2.824e-05, -3.088e-05, -1.538e-05,
#        -2.170e-06, -6.000e-07, -8.000e-08, -2.400e-07, -1.290e-06,
#        -1.310e-06, -1.260e-06, -1.020e-06, -9.100e-07, -8.300e-07,
#        -2.400e-07, -2.900e-07])

# %%
## barrier
barrier_values_5 = np.zeros(len(V_neg_5)-8)
inv_temp_truncated_2 = np.zeros(len(V_neg_5)-8)
kb = 8.617e-5
Astar = 120
A = 0.72
for i in range(len(V_neg_5)-8):
    barrier_values_5[i] = -kb/inv_temp[i]*np.log(-V_neg_5[i]/A/Astar*inv_temp[i]**2)
    inv_temp_truncated_2[i] = inv_temp[i]

# %%
barrier_values_3 = np.zeros(len(V_neg_3)-8)
kb = 8.617e-5
Astar = 120
A = 0.72
for i in range(len(V_neg_3)-8):
    barrier_values_3[i] = -kb/inv_temp[i]*np.log(-V_neg_3[i]/A/Astar*inv_temp[i]**2)

# %%
barrier_values_4 = np.zeros(len(V_neg_4)-8)
for i in range(len(V_neg_4)-8):
    barrier_values_4[i] = -kb/inv_temp[i]*np.log(-V_neg_4[i]/A/Astar*inv_temp[i]**2)
    
barrier_values_2 = np.zeros(len(V_neg_2)-8)
for i in range(len(V_neg_2)-8):
    barrier_values_2[i] = -kb/inv_temp[i]*np.log(-V_neg_2[i]/A/Astar*inv_temp[i]**2)
    
barrier_values_1 = np.zeros(len(V_neg_1)-8)
for i in range(len(V_neg_1)-8):
    barrier_values_1[i] = -kb/inv_temp[i]*np.log(-V_neg_1[i]/A/Astar*inv_temp[i]**2)

# %%
plt.scatter(inv_temp_truncated_2, barrier_values_5, label = '-5V', color = '#225ea8')
m5_new, b5_new = np.polyfit(inv_temp_truncated_2, barrier_values_5, 1)
print("m5 = ", "{:.4f}".format(m5_new), "b5 = ", "{:.4f}".format(b5_new))
plt.plot(inv_temp_truncated_2, m5_new*inv_temp_truncated_2 + b5_new, color = 'black')

plt.scatter(inv_temp_truncated_2, barrier_values_3, label = '-3V', color = '#1d91c0')
m3_new, b3_new = np.polyfit(inv_temp_truncated_2, barrier_values_3, 1)
print("m3 = ", "{:.4f}".format(m3_new), "b3 = ", "{:.4f}".format(b3_new))
plt.plot(inv_temp_truncated_2, m3_new*inv_temp_truncated_2 + b3_new, color = 'black')


plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in inv. K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$q\Phi_{B,\text{eff}}$")
plt.title("Effective Barrier Height vs 1/T")

plt.savefig('Effective_Heights.pdf', bbox_inches='tight')
# Out:
# m5 =  -75.8779 b5 =  0.9016
# m3 =  -121.1685 b3 =  1.1415

# %%
m4_new, b4_new = np.polyfit(inv_temp_truncated_2, barrier_values_4, 1)
print("m4 = ", "{:.4f}".format(m4_new), "b4 = ", "{:.4f}".format(b4_new))

m2_new, b2_new = np.polyfit(inv_temp_truncated_2, barrier_values_2, 1)
print("m2 = ", "{:.4f}".format(m2_new), "b2 = ", "{:.4f}".format(b2_new))

m1_new, b1_new = np.polyfit(inv_temp_truncated_2, barrier_values_1, 1)
print("m1 = ", "{:.4f}".format(m1_new), "b1 = ", "{:.4f}".format(b1_new))
# Out:
# m4 =  -100.5456 b4 =  1.0340
# m2 =  -143.9023 b2 =  1.2546
# m1 =  -156.7872 b1 =  1.3102

# %%
A = -m1_new*kb
print("{:.3e}".format(A))
# Out:
# 1.351e-02

# %% [markdown]
# ### Positive Bias

# %%
inv_V_pos_5 = np.zeros(len(V_5)-2)
inv_V_pos_4 = np.zeros(len(V_4)-2)
inv_V_pos_3 = np.zeros(len(V_3)-2)
inv_V_pos_2 = np.zeros(len(V_2)-2)
inv_V_pos_1 = np.zeros(len(V_1)-2)

for i in range(len(V_5)-2):
    inv_V_pos_5[i] = np.log(V_5[i]/int(Temp_values[i])**2)
    inv_V_pos_4[i] = np.log(V_4[i]/int(Temp_values[i])**2)
    inv_V_pos_3[i] = np.log(V_3[i]/int(Temp_values[i])**2)
    inv_V_pos_2[i] = np.log(V_2[i]/int(Temp_values[i])**2)
    inv_V_pos_1[i] = np.log(V_1[i]/int(Temp_values[i])**2)
    inv_temp[i] = 1/int(Temp_values[i])

# %%
plt.scatter(inv_temp, inv_V_pos_5, label = '5 V', color = '#225ea8')
plt.scatter(inv_temp, inv_V_pos_4, label = '4 V', color = '#1d91c0')
plt.scatter(inv_temp, inv_V_pos_3, label = '3 V', color = '#41b6c4')
plt.scatter(inv_temp, inv_V_pos_2, label = '2 V', color = '#7fcdbb')
plt.scatter(inv_temp, inv_V_pos_1, label = '1 V', color = '#c7e9b4')
plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in inv. K")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$ln(I/T^2)$")
plt.title("Au-Si $ln(I/T^2)$ vs $1/T$")
plt.savefig('Richardson_positive_voltages.pdf', bbox_inches='tight')

# %%
# truncating
inv_temp_trunc = np.zeros(len(inv_temp)-7)
inv_V_pos_5_trunc = np.zeros(len(inv_temp)-7)
inv_V_pos_4_trunc = np.zeros(len(inv_temp)-7)
inv_V_pos_3_trunc = np.zeros(len(inv_temp)-7)
inv_V_pos_2_trunc = np.zeros(len(inv_temp)-7)
inv_V_pos_1_trunc = np.zeros(len(inv_temp)-7)

for i in range(len(inv_temp)-7):
    inv_temp_trunc[i] = inv_temp[i]
    inv_V_pos_5_trunc[i] = inv_V_pos_5[i]
    inv_V_pos_4_trunc[i] = inv_V_pos_4[i]
    inv_V_pos_3_trunc[i] = inv_V_pos_3[i]
    inv_V_pos_2_trunc[i] = inv_V_pos_2[i]
    inv_V_pos_1_trunc[i] = inv_V_pos_1[i]

# %%
plt.scatter(inv_temp_trunc, inv_V_pos_5_trunc, label = '5 V', color = '#225ea8')
m5_pos, b5_pos = np.polyfit(inv_temp_trunc, inv_V_pos_5_trunc, 1)
print("m5_pos = ", "{:.5f}".format(m5_pos), "b5_pos = ", "{:.5f}".format(b5_pos))
plt.plot(inv_temp_trunc, m5_pos*inv_temp_trunc + b5_pos, color = 'red')

#plt.scatter(inv_temp_trunc, inv_V_neg_4_trunc, label = '-4 V', color = '#1d91c0')

plt.scatter(inv_temp_trunc, inv_V_pos_3_trunc, label = '3 V', color = '#41b6c4')
m3_pos, b3_pos = np.polyfit(inv_temp_trunc, inv_V_pos_3_trunc, 1)
print("m3 = ", "{:.5f}".format(m3_pos), "b3 = ", "{:.5f}".format(b3_pos))
plt.plot(inv_temp_trunc, m3_pos*inv_temp_trunc + b3_pos, color = 'red')

#plt.scatter(inv_temp_trunc, inv_V_neg_2_trunc, label = '-2 V', color = '#7fcdbb')
#plt.scatter(inv_temp_trunc, inv_V_neg_1_trunc, label = '-1 V', color = '#c7e9b4')

plt.legend(loc = 0)
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel("1/T in $K^{-1}$")
plt.xticks(fontsize=10, rotation=-45)
plt.ylabel("$\ln(I/T^2)$")
plt.title("$\ln(I/T^2)$ vs $1/T$ - Truncated with Linear Fits")
plt.savefig('Richardson_pos_voltages_trunc.pdf', bbox_inches='tight')
# Out:
# m5_pos =  537.07142 b5_pos =  -22.45774
# m3 =  419.74190 b3 =  -22.76977

# %% [markdown]
# ### Other Analysis (Older)

# %%
B = np.array([295, 285, 275, 265, 255, 245, 225, 200, 180, 160, 140,\
                       120, 100, 80, 60, 40, 20])
A = np.transpose(np.array([B,V_5]))
A
# Out:
# array([[2.9500e+02, 8.3580e-05],
#        [2.8500e+02, 8.9520e-05],
#        [2.7500e+02, 9.6190e-05],
#        [2.6500e+02, 1.0239e-04],
#        [2.5500e+02, 1.0223e-04],
#        [2.4500e+02, 1.0263e-04],
#        [2.2500e+02, 9.5280e-05],
#        [2.0000e+02, 9.6810e-05],
#        [1.8000e+02, 9.0070e-05],
#        [1.6000e+02, 7.5610e-05],
#        [1.4000e+02, 5.5670e-05],
#        [1.2000e+02, 3.7940e-05],
#        [1.0000e+02, 2.4550e-05],
#        [8.0000e+01, 1.4130e-05],
#        [6.0000e+01, 6.5800e-06],
#        [4.0000e+01, 1.9300e-06],
#        [2.0000e+01, 2.3000e-07]])

# %%
np.savetxt("output.txt", A)

# %%
q = -1.602E-19
kB = 1.3806E-23
A = 0.72
A_star = 120

# %%
def eta(b, temp):
    return q/kB/temp/b

# %%
eta(0.54565, 200)
# Out:
# -106.32869592872203

# %%
kB*200/q*np.log(120*200*200*0.72*10**6/7.6128)
# Out:
# -0.4626354736414727

# %%
def barrier(temp, I0):
    return kB*temp/q*np.log(A_star*temp**2/I0*A)

# %%
eta(0.5132, 295)
# Out:
# -76.64537951769182

# %%
2.503E-05
# Out:
# 2.503e-05

# %%
js = np.array([2.503E-05, 1.659E-05, 2.003E-05, 1.643E-05, 1.6526E-05, 1.169E-05, 1.0573E-05,\
               9.427E-06, 8.717E-06, 5.483E-06, 4.046E-06, 2.792E-06, 1.875E-06, 2.234E-06, 2.001E-06])

# %%
temp = np.array([295, 285, 275, 265, 255, 245, 225, 200, 180, 160, 140, 120, 100, 80, 60])

# %%
js = np.flip(js)
temp = np.flip(temp)

# %%
plt.scatter(temp, js)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.ylabel('Sat. Current Density $j_s$')
plt.xlabel('Temperature in K')
plt.grid()
#yikes 
plt.title("Saturation Density vs Temperature")
plt.savefig('sat_dens_temp.pdf', bbox_inches='tight')

# %%
np.transpose(js)
# Out:
# array([2.0010e-06, 2.2340e-06, 1.8750e-06, 2.7920e-06, 4.0460e-06,
#        5.4830e-06, 8.7170e-06, 9.4270e-06, 1.0573e-05, 1.1690e-05,
#        1.6526e-05, 1.6430e-05, 2.0030e-05, 1.6590e-05, 2.5030e-05])

# %%
inv_V_neg = np.zeros(len(V_neg_3)-2)
inv_temp = np.zeros(len(V_neg_3)-2)
for i in range(len(V_neg_3)-2):
    inv_V_neg[i] = V_neg_3[i]/int(Temp_values[i])**2
    inv_temp[i] = 1/int(Temp_values[i])

# %%
plt.scatter(inv_temp, inv_V_neg)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.ylabel('$\ln I/T^2$')
plt.xlabel('$1/T$ in K$^{-1}$')
plt.grid()
#yikes 
plt.title("$ln(I/T^2)$ vs $1/T$ for $-3V$")
plt.savefig('yolo.pdf', bbox_inches='tight')

# %%
inv_V_neg = np.zeros(len(V_5)-2)
inv_temp = np.zeros(len(V_5)-2)
for i in range(len(V_5)-2):
    inv_V_neg[i] = V_5[i]/int(Temp_values[i])**2
    inv_temp[i] = 1/int(Temp_values[i])

# %%
plt.plot(inv_temp, inv_V_neg)

# %%
inv_V_neg_3 = np.zeros(len(V_3))
for i in range(len(V_3)):
    inv_V_neg_3[i] = V_3[i]/int(Temp_values[i])**2

# %%
plt.plot(inv_temp, inv_V_neg_3)

# %%
inv_temp
# Out:
# array([0.00338983, 0.00350877, 0.00363636, 0.00377358, 0.00392157,
#        0.00408163, 0.00444444, 0.005     , 0.00555556, 0.00625   ,
#        0.00714286, 0.00833333, 0.01      , 0.0125    , 0.01666667,
#        0.025     , 0.05      ])

# %%
Temp_values
# Out:
# array(['295', '285', '275', '265', '255', '245', '225', '200', '180',
#        '160', '140', '120', '100', '80', '60', '40', '20'], dtype=object)
